# %%
import pandas as pd

# %%
# read and analyse csv file
# check for null - none found
BCN_2018= pd.read_excel(".\datasets\BCN_2018.xlsx")
BCN_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 6 columns):
# Country               636 non-null object
# Unnamed: 1            0 non-null float64
# Unnamed: 2            0 non-null float64
# Unnamed: 3            0 non-null float64
# Number of visitors    636 non-null object
# Month                 636 non-null object
# dtypes: float64(3), object(3)
# memory usage: 29.9+ KB

# %%
BCN_2018= BCN_2018.rename(columns = {"Number of visitors": "Number"})

# %%
BCN_2018
# Out:
#                                  Country  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                     Number of visitors         NaN         NaN         NaN
# 1             residents a Espanya                NaN         NaN         NaN
# 2         residents a l'estranger                NaN         NaN         NaN
# 3                             Alemanya           NaN         NaN         NaN
# 4                              Àustria           NaN         NaN         NaN
# 5                              Bèlgica           NaN         NaN         NaN
# 6                             Bulgària           NaN         NaN         NaN
# 7                                Xipre           NaN         NaN         NaN
# 8                              Croàcia           NaN         NaN         NaN
# 9                            Dinamarca           NaN         NaN         NaN
# 10                          Eslovàquia           NaN         NaN         NaN
# ...

# %% [markdown]
# #### Deleting Nan values

# %%
BCN_2018 = BCN_2018.drop(["Unnamed: 1", "Unnamed: 2", "Unnamed: 3"], axis=1)

# %% [markdown]
# #### changing number of visitors to float

# %%
BCN_2018 = BCN_2018.astype({"Number": float})

# %%
BCN_2018.head()
BCN_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 3 columns):
# Country    636 non-null object
# Number     636 non-null float64
# Month      636 non-null object
# dtypes: float64(1), object(2)
# memory usage: 15.0+ KB

# %%
BCN_2018.to_csv("BCN_2018_CLEAN.csv")

# %% [markdown]
# ## import to database

# %%
from sqlalchemy import create_engine
import pymysql

# %%
driver = "mysql+pymysql"
user = "root"
password = "Ir0nhack"
ip = "35.192.169.188"
database = "Project_2"

# %%
connection_string = f"{driver}://{user}:{password}@{ip}/{database}"

# %%
engine = create_engine(connection_string)

# %%
BCN_2018.to_sql("BCN_2018", engine)
