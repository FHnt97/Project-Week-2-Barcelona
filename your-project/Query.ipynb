# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## sum total number of tourist per nationality per year
# given info - number of tourist per nationaity per month
#
# #### sum the total number of tourists of year

# %%
BCN_2018 = pd.read_csv(".\clean_datasets\BCN_2018_CLEAN.csv")
BCN_2018.head()
# Out:
#    Unnamed: 0               Country   Number    Month
# 0           0            Alemanya    24885.0  January
# 1           1             Àustria     2705.0  January
# 2           2             Bèlgica     8075.0  January
# 3           3            Bulgària      575.0  January
# 4           4               Xipre      244.0  January

# %%
from sqlalchemy import create_engine
import pymysql

# %%
driver = "mysql+pymysql"
user = "root"
password = "Ir0nhack"
ip = "35.192.169.188"
database = "Project_2"

# %%
connection_string = f"{driver}://{user}:{password}@{ip}/{database}"

# %%
engine = create_engine(connection_string)

# %%
query = """ SELECT Country, SUM(Number) AS TOTAL
FROM BCN_2018
GROUP BY Country
ORDER BY TOTAL DESC
LIMIT 5
"""

# %%
pd.read_sql(query, engine)
# Out:
#                         Country     TOTAL
# 0                Estats Units    846595.0
# 1                  Regne Unit    678619.0
# 2                      França    655510.0
# 3                      Itàlia    509106.0
# 4                    Alemanya    425383.0
# 5                Resta d'Àsia    306296.0
# 6               Resta del món    297774.0
# 7            Resta d'Amèrica     238072.0

# %%
query = """ SELECT Country, SUM(Number) AS TOTAL
FROM BCN_2018
GROUP BY Country
ORDER BY TOTAL 
LIMIT 5
"""

# %%
pd.read_sql(query, engine)
# Out:
#                      Country   TOTAL
# 0            Liechtenstein    1418.0
# 1                    Xipre    4336.0
# 2                  Estònia    4482.0
# 3                Eslovènia    5094.0
# 4                    Malta    5197.0

# %% [markdown]
# ###  CAT total 2018

# %%
CAT = pd.read_csv(".\clean_datasets\CAT_TOTAL_CLEAN.csv")
CAT.head()
# Out:
#    Unnamed: 0 Month/year   Total  Germany  Belgium  France  Ireland  Italy  \
# 0           0   12/2018    977.2     58.6     14.6   199.0     11.9  100.6
# 1           1   11/2018   1040.7     71.3     23.9   193.9      8.9   76.0
# 2           2   10/2018   1655.6    129.4     22.3   311.1     29.0   94.1
# 3           3   09/2018   2005.3    162.9     41.8   343.0     33.4  117.2
# 4           4   08/2018   2439.0    186.7     57.6   755.5     45.1  160.9
#
#    Netherlands  Nordic countries  Portugal  United Kingdom  Russia  \
# 0         21.9              23.5       0.0            92.7    24.9
# 1         26.2              33.5       9.4            92.5    27.2
# 2         69.9              75.5       0.0           184.3    49.0
# 3         66.5              54.1      35.0           258.5   108.4
# 4        118.6              66.7      17.4           278.0   107.4
#
#    Switzerland  Rest of EU  United States  Rest of America  Rest of the world
# ...

# %%
import re

# %%
CAT["Month/year_error"] = CAT["Month/year"].apply(lambda x: "18" in x)
CAT.head()
CAT_2018 = CAT[CAT["Month/year_error"]==True]    


CAT_2018["Month/year_corrected"] = CAT_2018["Month/year"].apply(lambda x = x.replace(r'18^', "18"))


CAT_2018.to_csv("CAT_2018.csv")
# Out:
#   File "<ipython-input-110-059bdf2a4d7c>", line 6
#     CAT_2018["Month/year_corrected"] = CAT_2018["Month/year"].apply(lambda x = x.replace(r'18^', "18"))
#                                                                                                       ^
# SyntaxError: invalid syntax

# %%
# CAT_2018.to_sql("CAT_2018", engine)

# %%
totalg = CAT_2018["Germany"].sum()
print (totalg)

totals =[]
for i in CAT_2018:
    totals.append(int(CAT_2018[i].sum()))
print(totals)

total_values = totals[2:]

counry =
# Out:
# 1417.9
# [66, '12/2018 11/2018 10/2018 09/2018 08/2018 07/2018 06/2018 May-18Apr-18Mar-18Feb-18Jan-18', 19148.1, 1417.9, 401.7, 4136.7, 310.99999999999994, 1196.7, 736.6, 707.1, 173.3, 2086.7999999999997, 726.6, 246.9, 2255.1, 1359.8000000000002, 1081.6, 2292.2, 12]
# [19148.1, 1417.9, 401.7, 4136.7, 310.99999999999994, 1196.7, 736.6, 707.1, 173.3, 2086.7999999999997, 726.6, 246.9, 2255.1, 1359.8000000000002, 1081.6, 2292.2, 12]

# %%
CAT_2018.transpose()
# Out:
#                          0         1         2         3         4         5   \
# Unnamed: 0                0         1         2         3         4         5
# Month/year         12/2018   11/2018   10/2018   09/2018   08/2018   07/2018
# Total                 977.2    1040.7    1655.6    2005.3      2439    2385.7
# Germany                58.6      71.3     129.4     162.9     186.7     175.1
# Belgium                14.6      23.9      22.3      41.8      57.6      67.9
# France                  199     193.9     311.1       343     755.5       516
# Ireland                11.9       8.9        29      33.4      45.1      53.5
# Italy                 100.6        76      94.1     117.2     160.9     114.2
# Netherlands            21.9      26.2      69.9      66.5     118.6     153.1
# Nordic countries       23.5      33.5      75.5      54.1      66.7     125.3
# Portugal                  0       9.4         0        35      17.4      28.1
# ...

# %%
pd.read_sql(query, engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1243                     self.dialect.do_execute(
# -> 1244                         cursor, statement, parameters, context
#    1245                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     551     def do_execute(self, cursor, statement, parameters, context=None):
# --> 552         cursor.execute(statement, parameters)
#     553
#
# ~\AppData\Roaming\Python\Python37\site-packages\pymysql\cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# ...

# %% [markdown]
# ## Assumption variable

# %%
tot_CAT = # sum of all sums of country
tot_BCN = 11200
assumption_variable = tot_BCN/tot_CAT

# %%
# list of sum of country CAT * assumption_variable=
# lsit of tot_BCN per country

# top 5 coutnries CAT

# low 5 coutnries CAT
