# %%
import pandas as pd

# %%
# read and analyse csv file
# check for null - none found
BCN_2017= pd.read_excel(".\datasets\BCN_2017.xlsx")
BCN_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 6 columns):
# Country               603 non-null object
# Unnamed: 1            0 non-null float64
# Unnamed: 2            0 non-null float64
# Unnamed: 3            0 non-null float64
# Number of visitors    603 non-null object
# Month                 603 non-null object
# dtypes: float64(3), object(3)
# memory usage: 28.3+ KB

# %%
BCN_2017
# Out:
#                             Country  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                        Alemanya           NaN         NaN         NaN
# 1                         Àustria           NaN         NaN         NaN
# 2                         Bèlgica           NaN         NaN         NaN
# 3                        Bulgària           NaN         NaN         NaN
# 4                           Xipre           NaN         NaN         NaN
# 5                         Croàcia           NaN         NaN         NaN
# 6                       Dinamarca           NaN         NaN         NaN
# 7                      Eslovàquia           NaN         NaN         NaN
# 8                       Eslovènia           NaN         NaN         NaN
# 9                         Estònia           NaN         NaN         NaN
# 10                      Finlàndia           NaN         NaN         NaN
# 11                         França           NaN         NaN         NaN
# 12                         Grècia           NaN         NaN         NaN
# 13                        Hongria           NaN         NaN         NaN
# 14                        Irlanda           NaN         NaN         NaN
# 15                         Itàlia           NaN         NaN         NaN
# 16                        Letònia           NaN         NaN         NaN
# 17                       Lituània           NaN         NaN         NaN
# 18                      Luxemburg           NaN         NaN         NaN
# 19                          Malta           NaN         NaN         NaN
# 20                  Països Baixos           NaN         NaN         NaN
# 21                        Polònia           NaN         NaN         NaN
# 22                       Portugal           NaN         NaN         NaN
# 23                     Regne Unit           NaN         NaN         NaN
# 24                Republica Checa           NaN         NaN         NaN
# 25                        Romania           NaN         NaN         NaN
# 26                         Suècia           NaN         NaN         NaN
# 27             Resta Unió Europea           NaN         NaN         NaN
# 28                       Islàndia           NaN         NaN         NaN
# 29                  Liechtenstein           NaN         NaN         NaN
# ..                              ...         ...         ...         ...
# 573                 Països Baixos           NaN         NaN         NaN
# 574                       Polònia           NaN         NaN         NaN
# 575                      Portugal           NaN         NaN         NaN
# 576                    Regne Unit           NaN         NaN         NaN
# 577               Republica Checa           NaN         NaN         NaN
# 578                       Romania           NaN         NaN         NaN
# 579                        Suècia           NaN         NaN         NaN
# 580            Resta Unió Europea           NaN         NaN         NaN
# 581                      Islàndia           NaN         NaN         NaN
# 582                 Liechtenstein           NaN         NaN         NaN
# 583                       Noruega           NaN         NaN         NaN
# 584                        Rússia           NaN         NaN         NaN
# 585                        Suïssa           NaN         NaN         NaN
# 586                       Turquia           NaN         NaN         NaN
# 587                       Ucraïna           NaN         NaN         NaN
# 588                Resta d'Europa           NaN         NaN         NaN
# 589                     Argentina           NaN         NaN         NaN
# 590                        Brasil           NaN         NaN         NaN
# 591                        Canada           NaN         NaN         NaN
# 592                  Estats Units           NaN         NaN         NaN
# 593                         Mèxic           NaN         NaN         NaN
# 594              Resta d'Amèrica            NaN         NaN         NaN
# 595                     Sudàfrica           NaN         NaN         NaN
# 596                Resta d'Àfrica           NaN         NaN         NaN
# 597                          Japó           NaN         NaN         NaN
# 598                          Xina           NaN         NaN         NaN
# 599                 Corea Del Sud           NaN         NaN         NaN
# 600                  Resta d'Àsia           NaN         NaN         NaN
# 601                     Austràlia           NaN         NaN         NaN
# 602                 Resta del món           NaN         NaN         NaN
#
#     Number of visitors     Month
# 0              23374     January
# 1               2967     January
# 2               7922     January
# 3                655     January
# 4                668     January
# 5                345     January
# 6               3542     January
# 7                285     January
# 8                291     January
# 9                273     January
# 10              2779     January
# 11             44105     January
# 12              2513     January
# 13               976     January
# 14              4871     January
# 15             37248     January
# 16               499     January
# 17               548     January
# 18               331     January
# 19               279     January
# 20             12108     January
# 21              5045     January
# 22              6595     January
# 23             35496     January
# 24              1091     January
# 25              2201     January
# 26              4734     January
# 27              3366     January
# 28               204     January
# 29                86     January
# ..                 ...       ...
# 573             9419    December
# 574             3885    December
# 575             7188    December
# 576            31344    December
# 577             1184    December
# 578             1592    December
# 579             5136    December
# 580             2851    December
# 581              229    December
# 582               21    December
# 583             2573    December
# 584             8664    December
# 585             6574    December
# 586             2396    December
# 587             1078    December
# 588             6301    December
# 589             4071    December
# 590             6435    December
# 591             2745    December
# 592            29911    December
# 593             2741    December
# 594            13633    December
# 595              819    December
# 596             9081    December
# 597             9617    December
# 598             7812    December
# 599             3587    December
# 600            22383    December
# 601             3736    December
# 602            18296    December
#
# [603 rows x 6 columns]

# %% [markdown]
# #### new name for number of visitors

# %%
BCN_2017= BCN_2017.rename(columns = {"Number of visitors": "Number"})

# %% [markdown]
# #### deleting empty columns

# %%
BCN_2017 = BCN_2017.drop(["Unnamed: 1", "Unnamed: 2", "Unnamed: 3"], axis=1)

# %% [markdown]
# #### changing number of visitors to float

# %%
BCN_2017 = BCN_2017.astype({"Number": float})

# %%
BCN_2017.head()
BCN_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 3 columns):
# Country    636 non-null object
# Number     636 non-null float64
# Month      636 non-null object
# dtypes: float64(1), object(2)
# memory usage: 15.0+ KB

# %%
BCN_2017.to_csv("BCN_2017_CLEAN.csv")

# %% [markdown]
# ## import to database

# %%
from sqlalchemy import create_engine
import pymysql

# %%
driver = "mysql+pymysql"
user = "root"
password = "Ir0nhack"
ip = "35.192.169.188"
database = "Project_2"

# %%
connection_string = f"{driver}://{user}:{password}@{ip}/{database}"

# %%
engine = create_engine(connection_string)

# %%
BCN_2017.to_sql("BCN_2017", engine)
