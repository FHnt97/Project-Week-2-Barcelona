# %%
import pandas as pd

# %%
# read and analyse csv file
# check for null - none found
BCN_2016= pd.read_excel(".\datasets\BCN_2016.xlsx")
BCN_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 3 columns):
# Country    636 non-null object
# Number     636 non-null object
# Month      636 non-null object
# dtypes: object(3)
# memory usage: 15.0+ KB

# %%
BCN_2016
# Out:
#                                  Country     Number     Month
# 0         Nombre de viatgers              436.044     January
# 1             residents a Espanya         118.814     January
# 2         residents a l'estranger         317.230     January
# 3                             Alemanya     21.369     January
# 4                              Àustria      2.881     January
# 5                              Bèlgica      5.932     January
# 6                             Bulgària        683     January
# 7                                Xipre        291     January
# 8                              Croàcia        438     January
# 9                            Dinamarca      2.696     January
# 10                          Eslovàquia        531     January
# 11                           Eslovènia        406     January
# 12                             Estònia        278     January
# 13                           Finlàndia      2.824     January
# 14                              França     37.162     January
# 15                              Grècia      1.644     January
# 16                             Hongria      1.277     January
# 17                             Irlanda      5.095     January
# 18                              Itàlia     31.652     January
# 19                             Letònia        222     January
# 20                            Lituània        443     January
# 21                           Luxemburg        223     January
# 22                               Malta         99     January
# 23                       Països Baixos      8.550     January
# 24                             Polònia      4.337     January
# 25                            Portugal      5.313     January
# 26                          Regne Unit     32.935     January
# 27                     Republica Checa      1.124     January
# 28                             Romania      1.179     January
# 29                              Suècia      4.492     January
# ..                                   ...        ...       ...
# 606                      Països Baixos      8.477    December
# 607                            Polònia      3.672    December
# 608                           Portugal      7.608    December
# 609                         Regne Unit     33.549    December
# 610                    Republica Checa        963    December
# 611                            Romania      2.132    December
# 612                             Suècia      3.820    December
# 613                 Resta Unió Europea      2.857    December
# 614                           Islàndia        234    December
# 615                      Liechtenstein        101    December
# 616                            Noruega      2.801    December
# 617                             Rússia      7.636    December
# 618                             Suïssa      8.596    December
# 619                            Turquia      2.197    December
# 620                            Ucraïna      1.159    December
# 621                     Resta d'Europa      7.367    December
# 622                          Argentina      4.042    December
# 623                             Brasil      5.978    December
# 624                             Canada      3.643    December
# 625                       Estats Units     29.024    December
# 626                              Mèxic      2.692    December
# 627                   Resta d'Amèrica      11.218    December
# 628                          Sudàfrica        856    December
# 629                     Resta d'Àfrica     10.521    December
# 630                               Japó     11.539    December
# 631                               Xina      9.833    December
# 632                      Corea Del Sud      3.746    December
# 633                       Resta d'Àsia     20.534    December
# 634                          Austràlia      3.199    December
# 635                      Resta del món     20.482    December
#
# [636 rows x 3 columns]

# %% [markdown]
# #### changing number of visitors to float

# %%
BCN_2016 = BCN_2016.astype({"Number": float})

# %%
BCN_2016.head()
BCN_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 3 columns):
# Country    636 non-null object
# Number     636 non-null float64
# Month      636 non-null object
# dtypes: float64(1), object(2)
# memory usage: 15.0+ KB

# %%
BCN_2016.to_csv("BCN_2016_CLEAN.csv")

# %% [markdown]
# ## import to database

# %%
from sqlalchemy import create_engine
import pymysql

# %%
driver = "mysql+pymysql"
user = "root"
password = "Ir0nhack"
ip = "35.192.169.188"
database = "Project_2"

# %%
connection_string = f"{driver}://{user}:{password}@{ip}/{database}"

# %%
engine = create_engine(connection_string)

# %%
BCN_2016.to_sql("BCN_2016", engine)
