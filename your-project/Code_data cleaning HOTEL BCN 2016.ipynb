# %%
import pandas as pd

# %%
# read and analyse csv file
# check for null - none found
BCN_2016= pd.read_excel(".\datasets\BCN_2016.xlsx")
BCN_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 3 columns):
# Country    600 non-null object
# Number     600 non-null object
# Month      600 non-null object
# dtypes: object(3)
# memory usage: 14.1+ KB

# %%
BCN_2016
# Out:
#                             Country   Number     Month
# 0                        Alemanya    21369     January
# 1                         Àustria     2881     January
# 2                         Bèlgica     5932     January
# 3                        Bulgària      683     January
# 4                           Xipre      291     January
# 5                         Croàcia      438     January
# 6                       Dinamarca     2696     January
# 7                      Eslovàquia      531     January
# 8                       Eslovènia      406     January
# 9                         Estònia      278     January
# 10                      Finlàndia     2824     January
# 11                         França    37162     January
# 12                         Grècia     1644     January
# 13                        Hongria     1277     January
# 14                        Irlanda     5095     January
# 15                         Itàlia    31652     January
# ...

# %% [markdown]
# #### changing number of visitors to float

# %%
BCN_2016 = BCN_2016.astype({"Number": float})

# %%
BCN_2016.head()
BCN_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 3 columns):
# Country    600 non-null object
# Number     600 non-null float64
# Month      600 non-null object
# dtypes: float64(1), object(2)
# memory usage: 14.1+ KB

# %%
BCN_2016.to_csv("BCN_2016_CLEAN.csv")

# %% [markdown]
# ## import to database

# %%
from sqlalchemy import create_engine
import pymysql

# %%
driver = "mysql+pymysql"
user = "root"
password = "Ir0nhack"
ip = "35.192.169.188"
database = "Project_2"

# %%
connection_string = f"{driver}://{user}:{password}@{ip}/{database}"

# %%
engine = create_engine(connection_string)

# %%
BCN_2016.to_sql("BCN_2016", engine)
